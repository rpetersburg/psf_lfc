# %%
import numpy as np
import matplotlib.pyplot as plt

file = "hojoong_device_edfa_sweep.dat"

data = np.loadtxt(file)

# %%
wav = data[:,0]; trans = data[:,1]

plt.plot(wav,trans)
plt.yscale('log')
plt.show()
